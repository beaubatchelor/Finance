# %%
import pandas as pd
import time
from Functions import xbrl_dict,filings_collector
import datetime as dt
import requests
import xml.etree.ElementTree as ET
from pymongo import MongoClient

# %%
ticker = input('ticker?').lower()
# Out:
# ticker?gme

# %%
# Access page
all_filings_df = filings_collector(ticker)
all_filings_df.to_csv(f'../data/all_{ticker}_filings.csv', index=False)
all_filings_path = f'../data/all_{ticker}_filings.csv'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
all_filings_path = f'../data/all_{ticker}_filings.csv'
xml_filings_df = pd.read_csv(all_filings_path)
xml_filings_df = xml_filings_df.dropna(subset=['xbrl_link'])
xml_filings_df = xml_filings_df.reset_index(drop=True)
xml_filings_df.head(100)
# Out:
#       cik_num        date                                           doc_link  \
# 0   1326380.0  2019-04-02  https://www.sec.gov/Archives/edgar/data/132638...
# 1   1326380.0  2018-12-11  https://www.sec.gov/Archives/edgar/data/132638...
# 2   1326380.0  2018-09-11  https://www.sec.gov/Archives/edgar/data/132638...
# 3   1326380.0  2018-06-12  https://www.sec.gov/Archives/edgar/data/132638...
# 4   1326380.0  2018-04-02  https://www.sec.gov/Archives/edgar/data/132638...
# 5   1326380.0  2017-12-05  https://www.sec.gov/Archives/edgar/data/132638...
# 6   1326380.0  2017-09-06  https://www.sec.gov/Archives/edgar/data/132638...
# 7   1326380.0  2017-06-06  https://www.sec.gov/Archives/edgar/data/132638...
# 8   1326380.0  2017-03-27  https://www.sec.gov/Archives/edgar/data/132638...
# 9   1326380.0  2016-12-06  https://www.sec.gov/Archives/edgar/data/132638...
# 10  1326380.0  2016-09-07  https://www.sec.gov/Archives/edgar/data/132638...
# 11  1326380.0  2016-06-07  https://www.sec.gov/Archives/edgar/data/132638...
# 12  1326380.0  2016-03-29  https://www.sec.gov/Archives/edgar/data/132638...
# 13  1326380.0  2016-03-28  https://www.sec.gov/Archives/edgar/data/132638...
# 14  1326380.0  2015-12-08  https://www.sec.gov/Archives/edgar/data/132638...
# 15  1326380.0  2015-09-09  https://www.sec.gov/Archives/edgar/data/132638...
# 16  1326380.0  2015-06-09  https://www.sec.gov/Archives/edgar/data/132638...
# 17  1326380.0  2015-03-30  https://www.sec.gov/Archives/edgar/data/132638...
# 18  1326380.0  2014-12-10  https://www.sec.gov/Archives/edgar/data/132638...
# 19  1326380.0  2014-09-08  https://www.sec.gov/Archives/edgar/data/132638...
# 20  1326380.0  2014-06-12  https://www.sec.gov/Archives/edgar/data/132638...
# 21  1326380.0  2014-04-02  https://www.sec.gov/Archives/edgar/data/132638...
# 22  1326380.0  2013-12-11  https://www.sec.gov/Archives/edgar/data/132638...
# 23  1326380.0  2013-09-11  https://www.sec.gov/Archives/edgar/data/132638...
# 24  1326380.0  2013-06-13  https://www.sec.gov/Archives/edgar/data/132638...
# 25  1326380.0  2013-04-03  https://www.sec.gov/Archives/edgar/data/132638...
# 26  1326380.0  2012-12-05  https://www.sec.gov/Archives/edgar/data/132638...
# 27  1326380.0  2012-09-05  https://www.sec.gov/Archives/edgar/data/132638...
# 28  1326380.0  2012-06-06  https://www.sec.gov/Archives/edgar/data/132638...
# 29  1326380.0  2012-03-27  https://www.sec.gov/Archives/edgar/data/132638...
# 30  1326380.0  2011-12-07  https://www.sec.gov/Archives/edgar/data/132638...
# 16  https://www.sec.gov/Archives/edgar/data/132638...
# 17  https://www.sec.gov/Archives/edgar/data/132638...
# 18  https://www.sec.gov/Archives/edgar/data/132638...
# 19  https://www.sec.gov/Archives/edgar/data/132638...
# 20  https://www.sec.gov/Archives/edgar/data/132638...
# 21  https://www.sec.gov/Archives/edgar/data/132638...
# 22  https://www.sec.gov/Archives/edgar/data/132638...
# 23  https://www.sec.gov/Archives/edgar/data/132638...
# 24  https://www.sec.gov/Archives/edgar/data/132638...
# 25  https://www.sec.gov/Archives/edgar/data/132638...
# 26  https://www.sec.gov/Archives/edgar/data/132638...
# 27  https://www.sec.gov/Archives/edgar/data/132638...
# 28  https://www.sec.gov/Archives/edgar/data/132638...
# 29  https://www.sec.gov/Archives/edgar/data/132638...
# 30  https://www.sec.gov/Archives/edgar/data/132638...
# 31  https://www.sec.gov/Archives/edgar/data/132638...
# 32  https://www.sec.gov/Archives/edgar/data/132638...
# 33  https://www.sec.gov/Archives/edgar/data/132638...
# 34  https://www.sec.gov/Archives/edgar/data/132638...
# 35  https://www.sec.gov/Archives/edgar/data/132638...
# 36  https://www.sec.gov/Archives/edgar/data/132638...
# 37  https://www.sec.gov/Archives/edgar/data/132638...
# 38  https://www.sec.gov/Archives/edgar/data/132638...
# 39  https://www.sec.gov/Archives/edgar/data/132638...

# %%
# lxml_ten_df = xml_filings_df.loc[xml_filings_df['filings'] == '10-Q']
filings_list = []
for i in range(0,len(xml_filings_df)):
    lxml_link = xml_filings_df['xbrl_link'][i]

    lxml_dict = xbrl_dict(lxml_link)
    
    filings_list.append(lxml_dict)

# %%
all_data_df = pd.DataFrame(filings_list)
columns = all_data_df.columns.tolist()

# %%
establising_headers = ['company_name', 'CIK','doc_date',
              'doc_year','doc_period','common_shares_outstanding',
              'amendment_flag']
for header in establising_headers:
    index = columns.index(header)
    columns.pop(index)

ordered_columns = establising_headers+columns

# %%
all_data_df = all_data_df[ordered_columns]
all_data_df.tail(20)

# %%
all_years = []
for year in list(all_data_df['doc_year']):
    if year not in all_years:
         all_years.append(year)
counter = 1            
for index, row in all_data_df.iterrows():
#     year = row['doc_year']
#     period = row['doc_period']
    counter += 1
    print(row)
    print(counter)

# %%
all_data_df.to_csv(f'../data/{ticker}_financials.csv', index=False)

# %%
# Mongo DB connection
client = MongoClient('mongodb://localhost:27017')
db = client.Company_Info
collection = db.SEC_filings

for filing in filings_list:
    collection.insert(filing)

# %%
# uris = []
# all_names = []
# for i in range(0,len(xml_filings_df)):
#     lxml_link = xml_filings_df['xbrl_link'][i]
#     xbrl_resp = requests.get(lxml_link)
#     time.sleep(.1)
#     xbrl_str = xbrl_resp.text
#     root = ET.fromstring(xbrl_str)

#     #     defining namespace prefixes
#     uri_list = []
#     names = []
#     for child in root:
#         uri_pos = child.tag.index('}')
#         uri = ''.join(child.tag[1:uri_pos])
#         name = ''.join(child.tag[int(uri_pos+1):len(child.tag)])
        
#         if uri not in uri_list:
#             uri_list.append(uri)
        
#         if uri[0:18] == 'http://xbrl.us/dei':
#             names.append(f'{name}: {child.text}')
#     uris.append(uri_list)
#     all_names.append(names)

# %%
lxml_link = xml_filings_df['doc_link'][21]
print(lxml_link)
